# %%
# django widely used framework for building web applications
# from jupyter - !pip install django
# from cmd - python (or) py -m pip install django

# django - MVT framework
# Model View Templating architecture



# creating project
# from cmd - django-admin startproject simpleproject

# create a application
# cd simpleproject
# python manage.py startapp simpleapp

# edit simpleproject/simpleproject/settings.py
# INSTALLED_APPS = [
#          ....
#          'simpleapp'
#]

# current directory (simpleproject)
# start the application
# python manage.py runserver

# edit simpleproject/simpleapp/views.py

#from django.shortcuts import render
#from django.http import HttpResponse

#def index(request):
#    return HttpResponse("<h1>Welcome to Django app</h1>")
#    return render(request,"simpleapp/welcome.html")


# create a file (urls.py) simpleproject/simpleapp/urls.py
#from django.urls import path
#from . import views

#urlpatterns = [
#    path('welcome',views.index,name='index')
#]

# edit simpleproject/simpleproject/urls.py
# some existing content ...
# urlpatterns = [
#    path('admin/',.....),  --- existing
#    path('simpleapp/',include(('simpleapp.urls','simpleapp'),namespace='simpleapp'))
#]


# render a html page
# create a directory templates/simpleapp/  below simpleproject/simpleapp
# create a html page templates/simpleapp/welcome.html
#<!DOCTYPE html>
#<html lang="en">
#<head>
#    <meta charset="UTF-8">
#    <meta http-equiv="X-UA-Compatible" content="IE=edge">
#    <meta name="viewport" content="width=device-width, initial-scale=1.0">
#    <title>Document</title>
#</head>
#<body>
#    <h1>Welcome to Django - First Template</h1>
#</body>
#</html>


# sending data from application to html pages
# template is rendered using jinja2
# jinj2 allows us to embed applications variables inside templates

# modify views.py
# include some variables in render functions
# update view function below
#def index(request):
#    #return HttpResponse("<h1>Welcome to Django app</h1>")
#    msg = 'this is a test message from django application'
#    return render(request,"simpleapp/welcome.html",{'message': msg})
#    list_of_names =['bob','tom','pat','raj']
#    return render(request,"simpleapp/welcome.html",{'names': list_of_names})
#    list_of_names =[{'name':'bob'},{'name':'tom'},{'name':'pat'},{'name':'raj'}]
#    return render(request,"simpleapp/welcome.html",{'names': list_of_names})

# updatd welcome.html
#<!DOCTYPE html>
#<html lang="en">
#<head>
#    <meta charset="UTF-8">
#    <meta http-equiv="X-UA-Compatible" content="IE=edge">
#    <meta name="viewport" content="width=device-width, initial-scale=1.0">
#    <title>Document</title>
#</head>
#<body>
#    <h1>Welcome to Django - First Template</h1>
#    <p><h2>{{ message }}</h2></p>
#    <ul>
#        {% for obj in names %}
#        <li>{{ obj.name }}</li>
#        {% endfor %}
#    </ul>
#</body>
#</html>


# additional function added in simpleapp/views.py
#def getParameters(request):
#    if request.method == 'POST':
#        print(request.POST)
#    return redirect(reverse('simpleapp:index


# updatd welcome.html include form for posting data to application
#<!DOCTYPE html>
#<html lang="en">
#<head>
#    <meta charset="UTF-8">
#    <meta http-equiv="X-UA-Compatible" content="IE=edge">
#    <meta name="viewport" content="width=device-width, initial-scale=1.0">
#    <title>Document</title>
#</head>
#<body>
#    <h1>Welcome to Django - First Template</h1>
#    <p><h2>{{ message }}</h2></p>
#    <ul>
#        {% for obj in names %}
#        <li>{{ obj.name }}</li>
#        {% endfor %}
#    </ul>
#     <form action="{% url 'simpleapp:showparams' %}"  method="post">
#        {% csrf_token %}
#        <p>Name<input type="text" name="email" ></p>
#        <p><input type="text" name="organization" ></p>
#        <input type="submit" value="submit">
#     </form>
#</body>
#</html>
